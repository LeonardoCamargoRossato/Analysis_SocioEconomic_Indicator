# %%
import pandas as pd

# %%
df_Brazil = pd.read_csv('tabelas_csv/df_Brazil.csv',sep=',')
df_USA = pd.read_csv('tabelas_csv/df_USA.csv',sep=',')
df_Mexico = pd.read_csv('tabelas_csv/df_Mexico.csv',sep=',')
df_Peru = pd.read_csv('tabelas_csv/df_Peru.csv',sep=',')
df_ElSalvador = pd.read_csv('tabelas_csv/df_ElSalvador.csv',sep=',')
df_Chile = pd.read_csv('tabelas_csv/df_Chile.csv',sep=',')

# %%
df_Chile
# Out:
#            REGIÓN           COMUNA  BIENESTAR  ECONOMÍA  EDUCACIÓN  IDC_2020  \
# 0      VALPARAÍSO        ALGARROBO      811.1     134.8      638.2     411.7
# 1              RM            ALHUÉ      836.7      55.1      554.3     294.5
# 2          BIOBÍO      ALTO BIOBÍO      220.6      36.9      489.0     158.4
# 3              RM  ALTO DEL CARMEN      687.6      49.7      541.9     264.7
# 4        TARAPACÁ    ALTO HOSPICIO      866.4     118.3      680.3     411.5
# ..            ...              ...        ...       ...        ...       ...
# 340        BIOBÍO           YUMBEL      676.3      68.9      649.3     311.6
# 341  BIOBÍO-ÑUBLE           YUNGAY      740.9      93.9      695.3     364.4
# 342    VALPARAÍSO         ZAPALLAR      858.7     195.9      703.3     491.0
# 343  BIOBÍO-ÑUBLE           ÑIQUÉN      661.5      51.4      576.5     269.7
# 344            RM            ÑUÑOA      968.1     360.1      825.4     660.2
#
# ...

# %%
def country_states_list(df,country):
       if country in ['Brazil']:
           return list(df.UF.unique())
       elif country in ['USA','Mexico','Peru','ElSalvador']:
           return list(df.State.unique())
       elif country == 'Chile':
           return list(df.REGIÓN.unique())

# %%
# country_states_list(df=df_Brazil,country='USA')

# %%
df_Chile.REGIÓN.unique()
# Out:
# array(['VALPARAÍSO', 'RM', 'BIOBÍO', 'TARAPACÁ', 'LOS LAGOS', 'COQUIMBO',
#        'ARAUCANÍA', 'ANTOFAGASTA', 'ARICA Y PARINACOTA', 'AYSÉN',
#        'BIOBÍO-ÑUBLE', 'MAGALLANES', 'ATACAMA', 'MAULE', "O'HIGGINS",
#        'LOS RÍOS', 'LOS RIOS'], dtype=object)
